# %%
import traceback

try:
    a = int(input("Enter a number: "))
    print(a/0)
except Exception as e:
    print(traceback.format_exc())
else:
    print("No exceptions")
finally:
    print("All resources cleaned")
# Out:
# Enter a number:  30
# Traceback (most recent call last):
#   File "/var/folders/mb/r3g493vn02v3q47tzc7d31z80000gn/T/ipykernel_13213/2653611384.py", line 5, in <module>
#     print(a/0)
#           ~^~
# ZeroDivisionError: division by zero
#
# All resources cleaned

# %%
age = 17

if age < 18:
    raise ValueError("Age must be 18 or above")
else:
    print("You are eligible")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 4
#       1 age = 17
#       3 if age < 18:
# ----> 4     raise ValueError("Age must be 18 or above")
#       5 else:
#       6     print("You are eligible")
#
# ValueError: Age must be 18 or above

# %%
class MyError(Exception):
    pass

age = 17

if age < 18:
    raise MyError("Age must be 18 or above")
# Out:
# ---------------------------------------------------------------------------
# MyError                                   Traceback (most recent call last)
# Cell In[10], line 7
#       4 age = 17
#       6 if age < 18:
# ----> 7     raise MyError("Age must be 18 or above")
#
# MyError: Age must be 18 or above
